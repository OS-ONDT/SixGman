# %% [markdown]
# # *SixDman Basic Usage Example*
#
# > This notebook demonstrates the basic usage of the SixDman package for optical metro-urban network planning.

# %%
# Import Dependencies
import sys
from pathlib import Path
import os
import numpy as np
import pandas as pd
import json

# Ignore warnings to have clean cell outputs
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### *Create results directory if it doesn't exist*

# %%
# Get the current working directory (where the notebook is running)
base_dir = Path.cwd()

# Define the results directory
results_dir = base_dir.parent / "results" / "single_level"

# Create it if it doesn't exist
results_dir.mkdir(exist_ok=True)

print(f"Results will be saved in: {results_dir}")
# Out:
# Results will be saved in: /media/matin/DataDisk/University/Master/Project/Codes/SixDman_GitHub_Repo/SixDman/results/single_level

# %%
sys.path.append(os.path.abspath(base_dir.parent / 'src'))
from sixdman.core.network import Network
from sixdman.core.band import Band, OpticalParameters
from sixdman.core.planning import PlanningTool
from sixdman.core.post_process import analyse_result

# %%
# Get the current working directory (where the notebook is running)
base_dir = Path.cwd()

# Define the results directory
results_dir = base_dir.parent / "results" / "single_level"

# Create it if it doesn't exist
results_dir.mkdir(exist_ok=True)

print(f"Results will be saved in: {results_dir}")
# Out:
# Results will be saved in: /media/matin/DataDisk/University/Master/Project/Codes/SixDman_GitHub_Repo/SixDman/results/single_level

# %% [markdown]
# ### *1. Create Network Instance*

# %%
# Initialize network
network = Network(topology_name = 'MAN157')

# Load topology from .mat file
network.load_topology(filepath = '../data/MAN157Nodes.mat', matrixName ='MAN157Nodes')

# Set hierarchical levels
hl_dict = network.define_hierarchy(
    HL1_standalone = [1, 5],
    HL2_standalone = [0, 2, 3, 4],
    HL3_standalone = list(range(6, 39)),
    HL4_standalone = list(range(39, 157))
)

# %%
# Define variables for HL4 nodes
HL4_Standalone = hl_dict['HL4']['standalone']
HL4_colocated = hl_dict['HL4']['colocated']
HL4_all = np.concatenate((HL4_Standalone, HL4_colocated))

# %% [markdown]
# ### *2. Calculate candidate paths for standalone and colocated nodes*

# %%
# Define subnet matrix of HL4 nodes
_, subnetMatrix_HL4 = network.compute_hierarchy_subgraph(hierarchy_level = 4, minimum_hierarchy_level = 4)

# Calculate connected nodes to standalone HL4 nodes (candidate destinations)
HL4_connected_nodes = network.get_neighbor_nodes(HL4_Standalone)

# %% [markdown]
# #### *2.1 Candidate paths for standalone HL4s*

# %%
# Define CSV file_name for candidate paths for standalone HL4 nodes
file_name = results_dir / f"{network.topology_name}_HL4_K_path_attributes.csv"

# Check if the CSV file exists
if file_name.exists():
    # If the file exists -> load the CSV file containing candidate paths for standalone HL4 nodes
    K_path_attributes_df = pd.read_csv(file_name)
    K_path_attributes_df['links'] = K_path_attributes_df['links'].map(json.loads)
    K_path_attributes_df['nodes'] = K_path_attributes_df['nodes'].map(json.loads)
    
else:   
    # If the file doesn't exist -> calculate candidate paths 

    # Define number of candidate paths per node
    k_paths = 20

    # define a list to store path attributes
    K_path_attributes = []

    # iterate through each standalone HL4 node
    for src in HL4_Standalone:
        for dest in HL4_connected_nodes:
            # Calculate k_paths candidate paths for (src, dest) pair
            K_path_attributes = network.compute_k_shortest_paths(subnetMatrix_HL4, K_path_attributes, source = src, target = dest, k = k_paths)

    # Convert K_path_attributes list to dataframe
    K_path_attributes_df = pd.DataFrame(K_path_attributes)

    # save dataframe to csv file
    K_path_attributes_df.to_csv(file_name, index = False)

# %% [markdown]
# #### *2.2 Candidate paths for colocated HL4s*

# %%
# Define CSV file_name for candidate paths for colocated HL4 nodes
file_name = results_dir / f"{network.topology_name}_HL4_K_path_attributes_colocated.csv"

# Check if the CSV file exists
if file_name.exists():
    # If the file exists -> load the CSV file containing candidate paths for colocated HL4 nodes
    K_path_attributes_colocated_df = pd.read_csv(file_name)
    K_path_attributes_colocated_df['links'] = K_path_attributes_colocated_df['links'].map(json.loads)
    K_path_attributes_colocated_df['nodes'] = K_path_attributes_colocated_df['nodes'].map(json.loads)
else:
    # If the file doesn't exist -> calculate candidate paths 
    
    # Define number of candidate paths per node
    k_paths = 20

    # define a list to store path attributes
    K_path_attributes_colocated = []

    # iterate through each colocated HL node
    for src in HL4_colocated:
        for dest in HL4_connected_nodes:
            if src != dest: # check that the src and dest node aren't same
                # Calculate k_paths candidate paths for (src, dest) pair
                K_path_attributes_colocated = network.compute_k_shortest_paths(subnetMatrix_HL4, K_path_attributes_colocated, source = src, target = dest, k = k_paths)

    # Convert K_path_attributes list to dataframe
    K_path_attributes_colocated_df = pd.DataFrame(K_path_attributes_colocated)

    # save dataframe to csv file
    K_path_attributes_colocated_df.to_csv(file_name, index = False)

# %% [markdown]
# #### *2.3 Sort dataframes based on num_hops and distance (in order)*

# %%
K_path_attributes_df_sorted = K_path_attributes_df.groupby(['src_node'], group_keys = False).apply(lambda x: x.sort_values(['num_hops', 'distance']))
K_path_attributes_colocated_df_sorted = K_path_attributes_colocated_df.groupby(['src_node', 'dest_node'], group_keys = False).apply(lambda x: x.sort_values(['num_hops', 'distance']))

# %%
# Check for the first five member of standalone candidate paths dataframe
K_path_attributes_df_sorted.head()
# Out:
#     src_node  dest_node                               nodes  \
# 0         39          4                     [39, 40, 42, 4]
# 9         39          5                 [39, 41, 44, 45, 5]
# 10        39          5                 [39, 41, 44, 43, 5]
# 11        39          5      [39, 40, 42, 4, 53, 52, 54, 5]
# 1         39          4  [39, 41, 44, 45, 5, 54, 52, 53, 4]
#
#                                     links  distance  num_hops
# 0                          [118, 120, 27]      30.0         3
# 9                     [119, 121, 123, 31]      37.0         4
# 10                    [119, 121, 122, 30]      38.0         4
# 11       [118, 120, 27, 28, 131, 132, 33]      72.2         7
# 1   [119, 121, 123, 31, 33, 132, 131, 28]      79.2         8

# %% [markdown]
# #### *2.4 Calculate LAND pairs for each standalone HL4*

# %%
pairs_disjoint = network.land_pair_finder(HL4_Standalone, K_path_attributes_df_sorted, num_pairs = 1)

# %% [markdown]
# ### *3. Define Transmission Bands*

# %%
# Define C-band parameters
c_band_params = OpticalParameters(Rs_mat = 40e9)

# Create C-band instance
c_band = Band(
    name='C',
    start_freq = 190.65, # THz
    end_freq = 196.675, # THz
    opt_params = c_band_params,
    network_instance = network,
    channel_spacing = 0.05 # THz
    )

# Define L-band parameters
l_band_params = OpticalParameters(Rs_mat = 40e9)

# Create L-band instance
l_band = Band(
    name='L',
    start_freq = 184.525, # THz
    end_freq = 190.565, # THz
    opt_params = l_band_params,
    network_instance = network,
    channel_spacing = 0.05 # THz
)

# %%
# define C-band and L-band frequency slots
spectrum_C = c_band.calc_spectrum()
spectrum_L = l_band.calc_spectrum()

# concatenate C-band and KL-band to a sigle frequency spectrum
spectrum = np.concatenate((spectrum_C, spectrum_L))

f_c_axis = spectrum * 1e12  # Convert to Hz
Pch_dBm = np.arange(-6, -0.9, 0.1)  # Channel power in dBm
num_Ch_mat = np.arange(1, len(spectrum) - 1)  # Channel indices

# define total number of frequency slots
num_fslots = len(num_Ch_mat)

# %%
C_band_num_channels = int(4800 / 50)
supC_band_num_channels = int(1200 / 50)
L_band_num_channels = int(6000 / 50)

# %% [markdown]
# #### *3.1 Calculate HL4 links GSNR*

# %%
# Note that if the GSNR values calculated before, the function load the precalculated file
GSNR_opt_link, _, _, power_opt_link = c_band.process_link_gsnr(f_c_axis = f_c_axis, 
                                                                Pch_dBm = Pch_dBm, 
                                                                num_Ch_mat = num_Ch_mat,
                                                                spectrum_C = spectrum_C,
                                                                Nspan_array = np.ones(network.all_links.shape[0], dtype=int),
                                                                hierarchy_level = 4, 
                                                                minimum_hierarchy_level = 4,
                                                                result_directory = results_dir)
# Out:
# Loading precomputed link GSNR analysis

# %% [markdown]
# ### *4. Create Planning Tool and Optimize Network*

# %%
# Initialize planning tool
planner = PlanningTool(
    network_instance = network,
    bands = [c_band, l_band], # simulate network over C and L Band
    optical_parameters = c_band_params,
    grid_center = f_c_axis, 
    period_time = 10) # simulate network for 10 years

all_node_degree = network.get_node_degrees(np.arange(network.adjacency_matrix.shape[0]))[:, 1]

# %% [markdown]
# #### *4.1 Simulating aggregated traffic at HL4s*

# %%
planner.initialize_planner(num_fslots = num_fslots, 
                            hierarchy_level = 4,
                            minimum_hierarchy_level = 4, 
                            SR = 40 * 1e9, # Symbol rate of 50G channels (in Hz)
                            Max_bit_rate_BVT = np.array([400, 348, 280, 200, 120, 80]), # 400 Gbps BVTs
                            Ref_license_capacity = np.array([100, 87, 70, 50, 30, 20]), # reference license capacities corresponding to BVTs
                            FP_max_num = 20,
                            band_sepration_idx = [C_band_num_channels, 
                                                    C_band_num_channels + supC_band_num_channels])

# %%
# generate port capacity for HL4 nodes uisng Monte Carlo simulation
# Note that if the initial traffic profile calculated before, the function load the precalculated profile
planner.generate_initial_traffic_profile(num_nodes = len(HL4_all),
                                        optical_nodes = [], 
                                        monteCarlo_steps = 100,
                                        min_rate = 20, # Gbps
                                        max_rate = 200, # Gbps
                                        seed = 50, 
                                        result_directory = results_dir)

# Traffic growth simulation over 10 years
# Note that if the annual traffic profile calculated before, the function load the precalculated profile
planner.simulate_traffic_annual(lowest_hierarchy_dict = hl_dict['HL4'],
                                CAGR = 0.4, 
                                result_directory = results_dir)
# Out:
# Loading precomputed HL_capacity_final ...
# Loading precomputed Traffic Matrix ...

# %% [markdown]
# #### *4.2 Simulate network*

# %%
planner.run_planner(hierarchy_level = 4,
                    prev_hierarchy_level = 3,
                    pairs_disjoint = pairs_disjoint,
                    kpair_standalone = 1,
                    kpair_colocated = 1,
                    candidate_paths_standalone_df = K_path_attributes_df,
                    candidate_paths_colocated_df = K_path_attributes_colocated_df,
                    P_opt_links = power_opt_link,
                    GSNR_opt_link = GSNR_opt_link,
                    Nspan_array = np.ones(len(network.all_links), dtype = int),
                    all_node_degree = all_node_degree,
                    minimum_level = 4, 
                    node_cap_update_idx = 2,
                    result_directory = results_dir)

# Note that the results will save in the results directory
# Out:
# Processing Year:  1
# Processing standalone node 39
# Processing standalone node 40
# Processing standalone node 41
# Processing standalone node 42
# Processing standalone node 43
# Processing standalone node 44
# Processing standalone node 45
# Processing standalone node 46
# Processing standalone node 47
# Processing standalone node 48
# Processing standalone node 49
# Processing standalone node 50
# Processing standalone node 51
# Processing standalone node 52
# Processing standalone node 53
# Processing standalone node 54
# Processing standalone node 55
# Processing standalone node 56
# Processing standalone node 57
# Processing standalone node 58
# Processing standalone node 59
# Processing standalone node 60
# Processing standalone node 61
# Processing standalone node 62
# Processing standalone node 63
# Processing standalone node 64
# Processing standalone node 65
# Processing standalone node 66
# Processing standalone node 67
# Processing standalone node 68
# Processing standalone node 69
# Processing standalone node 70
# Processing standalone node 71
# Processing standalone node 72
# Processing standalone node 73
# Processing standalone node 74
# Processing standalone node 75
# Processing standalone node 76
# Processing standalone node 77
# Processing standalone node 78
# Processing standalone node 79
# Processing standalone node 80
# Processing standalone node 81
# Processing standalone node 82
# Processing standalone node 83
# Processing standalone node 84
# Processing standalone node 85
# Processing standalone node 86
# Processing standalone node 87
# Processing standalone node 88
# Processing standalone node 89
# Processing standalone node 90
# Processing standalone node 91
# Processing standalone node 92
# Processing standalone node 93
# Processing standalone node 94
# Processing standalone node 95
# Processing standalone node 96
# Processing standalone node 97
# Processing standalone node 98
# Processing standalone node 99
# Processing standalone node 100
# Processing standalone node 101
# Processing standalone node 102
# Processing standalone node 103
# Processing standalone node 104
# Processing standalone node 105
# Processing standalone node 106
# Processing standalone node 107
# Processing standalone node 108
# Processing standalone node 109
# Processing standalone node 110
# Processing standalone node 111
# Processing standalone node 112
# Processing standalone node 113
# Processing standalone node 114
# Processing standalone node 115
# Processing standalone node 116
# Processing standalone node 117
# Processing standalone node 118
# Processing standalone node 119
# Processing standalone node 120
# Processing standalone node 121
# Processing standalone node 122
# Processing standalone node 123
# Processing standalone node 124
# Processing standalone node 125
# Processing standalone node 126
# Processing standalone node 127
# Processing standalone node 128
# Processing standalone node 129
# Processing standalone node 130
# Processing standalone node 131
# Processing standalone node 132
# Processing standalone node 133
# Processing standalone node 134
# Processing standalone node 135
# Processing standalone node 136
# Processing standalone node 137
# Processing standalone node 138
# Processing standalone node 139
# Processing standalone node 140
# Processing standalone node 141
# Processing standalone node 142
# Processing standalone node 143
# Processing standalone node 144
# Processing standalone node 145
# Processing standalone node 146
# Processing standalone node 147
# Processing standalone node 148
# Processing standalone node 149
# Processing standalone node 150
# Processing standalone node 151
# Processing standalone node 152
# Processing standalone node 153
# Processing standalone node 154
# Processing standalone node 155
# Processing standalone node 156
# Processing colocated node 0
# Processing colocated node 1
# Processing colocated node 2
# Processing colocated node 3
# Processing colocated node 4
# Processing colocated node 5
# Processing colocated node 6
# Processing colocated node 7
# Processing colocated node 8
# Processing colocated node 9
# Processing colocated node 10
# Processing colocated node 11
# Processing colocated node 12
# Processing colocated node 13
# Processing colocated node 14
# Processing colocated node 15
# Processing colocated node 16
# Processing colocated node 17
# Processing colocated node 18
# Processing colocated node 19
# Processing colocated node 20
# Processing colocated node 21
# Processing colocated node 22
# Processing colocated node 23
# Processing colocated node 24
# Processing colocated node 25
# Processing colocated node 26
# Processing colocated node 27
# Processing colocated node 28
# Processing colocated node 29
# Processing colocated node 30
# Processing colocated node 31
# Processing colocated node 32
# Processing colocated node 33
# Processing colocated node 34
# Processing colocated node 35
# Processing colocated node 36
# Processing colocated node 37
# Processing colocated node 38
# Processing Year:  2
# Processing standalone node 39
# Processing standalone node 40
# Processing standalone node 41
# Processing standalone node 42
# Processing standalone node 43
# Processing standalone node 44
# Processing standalone node 45
# Processing standalone node 46
# Processing standalone node 47
# Processing standalone node 48
# Processing standalone node 49
# Processing standalone node 50
# Processing standalone node 51
# Processing standalone node 52
# Processing standalone node 53
# Processing standalone node 54
# Processing standalone node 55
# Processing standalone node 56
# Processing standalone node 57
# Processing standalone node 58
# Processing standalone node 59
# Processing standalone node 60
# Processing standalone node 61
# Processing standalone node 62
# Processing standalone node 63
# Processing standalone node 64
# Processing standalone node 65
# Processing standalone node 66
# Processing standalone node 67
# Processing standalone node 68
# Processing standalone node 69
# Processing standalone node 70
# Processing standalone node 71
# Processing standalone node 72
# Processing standalone node 73
# Processing standalone node 74
# Processing standalone node 75
# Processing standalone node 76
# Processing standalone node 77
# Processing standalone node 78
# Processing standalone node 79
# Processing standalone node 80
# Processing standalone node 81
# Processing standalone node 82
# Processing standalone node 83
# Processing standalone node 84
# Processing standalone node 85
# Processing standalone node 86
# Processing standalone node 87
# Processing standalone node 88
# Processing standalone node 89
# Processing standalone node 90
# Processing standalone node 91
# Processing standalone node 92
# Processing standalone node 93
# Processing standalone node 94
# Processing standalone node 95
# Processing standalone node 96
# Processing standalone node 97
# Processing standalone node 98
# Processing standalone node 99
# Processing standalone node 100
# Processing standalone node 101
# Processing standalone node 102
# Processing standalone node 103
# Processing standalone node 104
# Processing standalone node 105
# Processing standalone node 106
# Processing standalone node 107
# Processing standalone node 108
# Processing standalone node 109
# Processing standalone node 110
# Processing standalone node 111
# Processing standalone node 112
# Processing standalone node 113
# Processing standalone node 114
# Processing standalone node 115
# Processing standalone node 116
# Processing standalone node 117
# Processing standalone node 118
# Processing standalone node 119
# Processing standalone node 120
# Processing standalone node 121
# Processing standalone node 122
# Processing standalone node 123
# Processing standalone node 124
# Processing standalone node 125
# Processing standalone node 126
# Processing standalone node 127
# Processing standalone node 128
# Processing standalone node 129
# Processing standalone node 130
# Processing standalone node 131
# Processing standalone node 132
# Processing standalone node 133
# Processing standalone node 134
# Processing standalone node 135
# Processing standalone node 136
# Processing standalone node 137
# Processing standalone node 138
# Processing standalone node 139
# Processing standalone node 140
# Processing standalone node 141
# Processing standalone node 142
# Processing standalone node 143
# Processing standalone node 144
# Processing standalone node 145
# Processing standalone node 146
# Processing standalone node 147
# Processing standalone node 148
# Processing standalone node 149
# Processing standalone node 150
# Processing standalone node 151
# Processing standalone node 152
# Processing standalone node 153
# Processing standalone node 154
# Processing standalone node 155
# Processing standalone node 156
# Processing colocated node 0
# Processing colocated node 1
# Processing colocated node 2
# Processing colocated node 3
# Processing colocated node 4
# Processing colocated node 5
# Processing colocated node 6
# Processing colocated node 7
# Processing colocated node 8
# Processing colocated node 9
# Processing colocated node 10
# Processing colocated node 11
# Processing colocated node 12
# Processing colocated node 13
# Processing colocated node 14
# Processing colocated node 15
# Processing colocated node 16
# Processing colocated node 17
# Processing colocated node 18
# Processing colocated node 19
# Processing colocated node 20
# Processing colocated node 21
# Processing colocated node 22
# Processing colocated node 23
# Processing colocated node 24
# Processing colocated node 25
# Processing colocated node 26
# Processing colocated node 27
# Processing colocated node 28
# Processing colocated node 29
# Processing colocated node 30
# Processing colocated node 31
# Processing colocated node 32
# Processing colocated node 33
# Processing colocated node 34
# Processing colocated node 35
# Processing colocated node 36
# Processing colocated node 37
# Processing colocated node 38
# Processing Year:  3
# Processing standalone node 39
# Processing standalone node 40
# Processing standalone node 41
# Processing standalone node 42
# Processing standalone node 43
# Processing standalone node 44
# Processing standalone node 45
# Processing standalone node 46
# Processing standalone node 47
# Processing standalone node 48
# Processing standalone node 49
# Processing standalone node 50
# Processing standalone node 51
# Processing standalone node 52
# Processing standalone node 53
# Processing standalone node 54
# Processing standalone node 55
# Processing standalone node 56
# Processing standalone node 57
# Processing standalone node 58
# Processing standalone node 59
# Processing standalone node 60
# Processing standalone node 61
# Processing standalone node 62
# Processing standalone node 63
# Processing standalone node 64
# Processing standalone node 65
# Processing standalone node 66
# Processing standalone node 67
# Processing standalone node 68
# Processing standalone node 69
# Processing standalone node 70
# Processing standalone node 71
# Processing standalone node 72
# Processing standalone node 73
# Processing standalone node 74
# Processing standalone node 75
# Processing standalone node 76
# Processing standalone node 77
# Processing standalone node 78
# Processing standalone node 79
# Processing standalone node 80
# Processing standalone node 81
# Processing standalone node 82
# Processing standalone node 83
# Processing standalone node 84
# Processing standalone node 85
# Processing standalone node 86
# Processing standalone node 87
# Processing standalone node 88
# Processing standalone node 89
# Processing standalone node 90
# Processing standalone node 91
# Processing standalone node 92
# Processing standalone node 93
# Processing standalone node 94
# Processing standalone node 95
# Processing standalone node 96
# Processing standalone node 97
# Processing standalone node 98
# Processing standalone node 99
# Processing standalone node 100
# Processing standalone node 101
# Processing standalone node 102
# Processing standalone node 103
# Processing standalone node 104
# Processing standalone node 105
# Processing standalone node 106
# Processing standalone node 107
# Processing standalone node 108
# Processing standalone node 109
# Processing standalone node 110
# Processing standalone node 111
# Processing standalone node 112
# Processing standalone node 113
# Processing standalone node 114
# Processing standalone node 115
# Processing standalone node 116
# Processing standalone node 117
# Processing standalone node 118
# Processing standalone node 119
# Processing standalone node 120
# Processing standalone node 121
# Processing standalone node 122
# Processing standalone node 123
# Processing standalone node 124
# Processing standalone node 125
# Processing standalone node 126
# Processing standalone node 127
# Processing standalone node 128
# Processing standalone node 129
# Processing standalone node 130
# Processing standalone node 131
# Processing standalone node 132
# Processing standalone node 133
# Processing standalone node 134
# Processing standalone node 135
# Processing standalone node 136
# Processing standalone node 137
# Processing standalone node 138
# Processing standalone node 139
# Processing standalone node 140
# Processing standalone node 141
# Processing standalone node 142
# Processing standalone node 143
# Processing standalone node 144
# Processing standalone node 145
# Processing standalone node 146
# Processing standalone node 147
# Processing standalone node 148
# Processing standalone node 149
# Processing standalone node 150
# Processing standalone node 151
# Processing standalone node 152
# Processing standalone node 153
# Processing standalone node 154
# Processing standalone node 155
# Processing standalone node 156
# Processing colocated node 0
# Processing colocated node 1
# Processing colocated node 2
# Processing colocated node 3
# Processing colocated node 4
# Processing colocated node 5
# Processing colocated node 6
# Processing colocated node 7
# Processing colocated node 8
# Processing colocated node 9
# Processing colocated node 10
# Processing colocated node 11
# Processing colocated node 12
# Processing colocated node 13
# Processing colocated node 14
# Processing colocated node 15
# Processing colocated node 16
# Processing colocated node 17
# Processing colocated node 18
# Processing colocated node 19
# Processing colocated node 20
# Processing colocated node 21
# Processing colocated node 22
# Processing colocated node 23
# Processing colocated node 24
# Processing colocated node 25
# Processing colocated node 26
# Processing colocated node 27
# Processing colocated node 28
# Processing colocated node 29
# Processing colocated node 30
# Processing colocated node 31
# Processing colocated node 32
# Processing colocated node 33
# Processing colocated node 34
# Processing colocated node 35
# Processing colocated node 36
# Processing colocated node 37
# Processing colocated node 38
# Processing Year:  4
# Processing standalone node 39
# Processing standalone node 40
# Processing standalone node 41
# Processing standalone node 42
# Processing standalone node 43
# Processing standalone node 44
# Processing standalone node 45
# Processing standalone node 46
# Processing standalone node 47
# Processing standalone node 48
# Processing standalone node 49
# Processing standalone node 50
# Processing standalone node 51
# Processing standalone node 52
# Processing standalone node 53
# Processing standalone node 54
# Processing standalone node 55
# Processing standalone node 56
# Processing standalone node 57
# Processing standalone node 58
# Processing standalone node 59
# Processing standalone node 60
# Processing standalone node 61
# Processing standalone node 62
# Processing standalone node 63
# Processing standalone node 64
# Processing standalone node 65
# Processing standalone node 66
# Processing standalone node 67
# Processing standalone node 68
# Processing standalone node 69
# Processing standalone node 70
# Processing standalone node 71
# Processing standalone node 72
# Processing standalone node 73
# Processing standalone node 74
# Processing standalone node 75
# Processing standalone node 76
# Processing standalone node 77
# Processing standalone node 78
# Processing standalone node 79
# Processing standalone node 80
# Processing standalone node 81
# Processing standalone node 82
# Processing standalone node 83
# Processing standalone node 84
# Processing standalone node 85
# Processing standalone node 86
# Processing standalone node 87
# Processing standalone node 88
# Processing standalone node 89
# Processing standalone node 90
# Processing standalone node 91
# Processing standalone node 92
# Processing standalone node 93
# Processing standalone node 94
# Processing standalone node 95
# Processing standalone node 96
# Processing standalone node 97
# Processing standalone node 98
# Processing standalone node 99
# Processing standalone node 100
# Processing standalone node 101
# Processing standalone node 102
# Processing standalone node 103
# Processing standalone node 104
# Processing standalone node 105
# Processing standalone node 106
# Processing standalone node 107
# Processing standalone node 108
# Processing standalone node 109
# Processing standalone node 110
# Processing standalone node 111
# Processing standalone node 112
# Processing standalone node 113
# Processing standalone node 114
# Processing standalone node 115
# Processing standalone node 116
# Processing standalone node 117
# Processing standalone node 118
# Processing standalone node 119
# Processing standalone node 120
# Processing standalone node 121
# Processing standalone node 122
# Processing standalone node 123
# Processing standalone node 124
# Processing standalone node 125
# Processing standalone node 126
# Processing standalone node 127
# Processing standalone node 128
# Processing standalone node 129
# Processing standalone node 130
# Processing standalone node 131
# Processing standalone node 132
# Processing standalone node 133
# Processing standalone node 134
# Processing standalone node 135
# Processing standalone node 136
# Processing standalone node 137
# Processing standalone node 138
# Processing standalone node 139
# Processing standalone node 140
# Processing standalone node 141
# Processing standalone node 142
# Processing standalone node 143
# Processing standalone node 144
# Processing standalone node 145
# Processing standalone node 146
# Processing standalone node 147
# Processing standalone node 148
# Processing standalone node 149
# Processing standalone node 150
# Processing standalone node 151
# Processing standalone node 152
# Processing standalone node 153
# Processing standalone node 154
# Processing standalone node 155
# Processing standalone node 156
# Processing colocated node 0
# Processing colocated node 1
# Processing colocated node 2
# Processing colocated node 3
# Processing colocated node 4
# Processing colocated node 5
# Processing colocated node 6
# Processing colocated node 7
# Processing colocated node 8
# Processing colocated node 9
# Processing colocated node 10
# Processing colocated node 11
# Processing colocated node 12
# Processing colocated node 13
# Processing colocated node 14
# Processing colocated node 15
# Processing colocated node 16
# Processing colocated node 17
# Processing colocated node 18
# Processing colocated node 19
# Processing colocated node 20
# Processing colocated node 21
# Processing colocated node 22
# Processing colocated node 23
# Processing colocated node 24
# Processing colocated node 25
# Processing colocated node 26
# Processing colocated node 27
# Processing colocated node 28
# Processing colocated node 29
# Processing colocated node 30
# Processing colocated node 31
# Processing colocated node 32
# Processing colocated node 33
# Processing colocated node 34
# Processing colocated node 35
# Processing colocated node 36
# Processing colocated node 37
# Processing colocated node 38
# Processing Year:  5
# Processing standalone node 39
# Processing standalone node 40
# Processing standalone node 41
# Processing standalone node 42
# Processing standalone node 43
# Processing standalone node 44
# Processing standalone node 45
# Processing standalone node 46
# Processing standalone node 47
# Processing standalone node 48
# Processing standalone node 49
# Processing standalone node 50
# Processing standalone node 51
# Processing standalone node 52
# Processing standalone node 53
# Processing standalone node 54
# Processing standalone node 55
# Processing standalone node 56
# Processing standalone node 57
# Processing standalone node 58
# Processing standalone node 59
# Processing standalone node 60
# Processing standalone node 61
# Processing standalone node 62
# Processing standalone node 63
# Processing standalone node 64
# Processing standalone node 65
# Processing standalone node 66
# Processing standalone node 67
# Processing standalone node 68
# Processing standalone node 69
# Processing standalone node 70
# Processing standalone node 71
# Processing standalone node 72
# Processing standalone node 73
# Processing standalone node 74
# Processing standalone node 75
# Processing standalone node 76
# Processing standalone node 77
# Processing standalone node 78
# Processing standalone node 79
# Processing standalone node 80
# Processing standalone node 81
# Processing standalone node 82
# Processing standalone node 83
# Processing standalone node 84
# Processing standalone node 85
# Processing standalone node 86
# Processing standalone node 87
# Processing standalone node 88
# Processing standalone node 89
# Processing standalone node 90
# Processing standalone node 91
# Processing standalone node 92
# Processing standalone node 93
# Processing standalone node 94
# Processing standalone node 95
# Processing standalone node 96
# Processing standalone node 97
# Processing standalone node 98
# Processing standalone node 99
# Processing standalone node 100
# Processing standalone node 101
# Processing standalone node 102
# Processing standalone node 103
# Processing standalone node 104
# Processing standalone node 105
# Processing standalone node 106
# Processing standalone node 107
# Processing standalone node 108
# Processing standalone node 109
# Processing standalone node 110
# Processing standalone node 111
# Processing standalone node 112
# Processing standalone node 113
# Processing standalone node 114
# Processing standalone node 115
# Processing standalone node 116
# Processing standalone node 117
# Processing standalone node 118
# Processing standalone node 119
# Processing standalone node 120
# Processing standalone node 121
# Processing standalone node 122
# Processing standalone node 123
# Processing standalone node 124
# Processing standalone node 125
# Processing standalone node 126
# Processing standalone node 127
# Processing standalone node 128
# Processing standalone node 129
# Processing standalone node 130
# Processing standalone node 131
# Processing standalone node 132
# Processing standalone node 133
# Processing standalone node 134
# Processing standalone node 135
# Processing standalone node 136
# Processing standalone node 137
# Processing standalone node 138
# Processing standalone node 139
# Processing standalone node 140
# Processing standalone node 141
# Processing standalone node 142
# Processing standalone node 143
# Processing standalone node 144
# Processing standalone node 145
# Processing standalone node 146
# Processing standalone node 147
# Processing standalone node 148
# Processing standalone node 149
# Processing standalone node 150
# Processing standalone node 151
# Processing standalone node 152
# Processing standalone node 153
# Processing standalone node 154
# Processing standalone node 155
# Processing standalone node 156
# Processing colocated node 0
# Processing colocated node 1
# Processing colocated node 2
# Processing colocated node 3
# Processing colocated node 4
# Processing colocated node 5
# Processing colocated node 6
# Processing colocated node 7
# Processing colocated node 8
# Processing colocated node 9
# Processing colocated node 10
# Processing colocated node 11
# Processing colocated node 12
# Processing colocated node 13
# Processing colocated node 14
# Processing colocated node 15
# Processing colocated node 16
# Processing colocated node 17
# Processing colocated node 18
# Processing colocated node 19
# Processing colocated node 20
# Processing colocated node 21
# Processing colocated node 22
# Processing colocated node 23
# Processing colocated node 24
# Processing colocated node 25
# Processing colocated node 26
# Processing colocated node 27
# Processing colocated node 28
# Processing colocated node 29
# Processing colocated node 30
# Processing colocated node 31
# Processing colocated node 32
# Processing colocated node 33
# Processing colocated node 34
# Processing colocated node 35
# Processing colocated node 36
# Processing colocated node 37
# Processing colocated node 38
# Processing Year:  6
# Processing standalone node 39
# Processing standalone node 40
# Processing standalone node 41
# Processing standalone node 42
# Processing standalone node 43
# Processing standalone node 44
# Processing standalone node 45
# Processing standalone node 46
# Processing standalone node 47
# Processing standalone node 48
# Processing standalone node 49
# Processing standalone node 50
# Processing standalone node 51
# Processing standalone node 52
# Processing standalone node 53
# Processing standalone node 54
# Processing standalone node 55
# Processing standalone node 56
# Processing standalone node 57
# Processing standalone node 58
# Processing standalone node 59
# Processing standalone node 60
# Processing standalone node 61
# Processing standalone node 62
# Processing standalone node 63
# Processing standalone node 64
# Processing standalone node 65
# Processing standalone node 66
# Processing standalone node 67
# Processing standalone node 68
# Processing standalone node 69
# Processing standalone node 70
# Processing standalone node 71
# Processing standalone node 72
# Processing standalone node 73
# Processing standalone node 74
# Processing standalone node 75
# Processing standalone node 76
# Processing standalone node 77
# Processing standalone node 78
# Processing standalone node 79
# Processing standalone node 80
# Processing standalone node 81
# Processing standalone node 82
# Processing standalone node 83
# Processing standalone node 84
# Processing standalone node 85
# Processing standalone node 86
# Processing standalone node 87
# Processing standalone node 88
# Processing standalone node 89
# Processing standalone node 90
# Processing standalone node 91
# Processing standalone node 92
# Processing standalone node 93
# Processing standalone node 94
# Processing standalone node 95
# Processing standalone node 96
# Processing standalone node 97
# Processing standalone node 98
# Processing standalone node 99
# Processing standalone node 100
# Processing standalone node 101
# Processing standalone node 102
# Processing standalone node 103
# Processing standalone node 104
# Processing standalone node 105
# Processing standalone node 106
# Processing standalone node 107
# Processing standalone node 108
# Processing standalone node 109
# Processing standalone node 110
# Processing standalone node 111
# Processing standalone node 112
# Processing standalone node 113
# Processing standalone node 114
# Processing standalone node 115
# Processing standalone node 116
# Processing standalone node 117
# Processing standalone node 118
# Processing standalone node 119
# Processing standalone node 120
# Processing standalone node 121
# Processing standalone node 122
# Processing standalone node 123
# Processing standalone node 124
# Processing standalone node 125
# Processing standalone node 126
# Processing standalone node 127
# Processing standalone node 128
# Processing standalone node 129
# Processing standalone node 130
# Processing standalone node 131
# Processing standalone node 132
# Processing standalone node 133
# Processing standalone node 134
# Processing standalone node 135
# Processing standalone node 136
# Processing standalone node 137
# Processing standalone node 138
# Processing standalone node 139
# Processing standalone node 140
# Processing standalone node 141
# Processing standalone node 142
# Processing standalone node 143
# Processing standalone node 144
# Processing standalone node 145
# Processing standalone node 146
# Processing standalone node 147
# Processing standalone node 148
# Processing standalone node 149
# Processing standalone node 150
# Processing standalone node 151
# Processing standalone node 152
# Processing standalone node 153
# Processing standalone node 154
# Processing standalone node 155
# Processing standalone node 156
# Processing colocated node 0
# Processing colocated node 1
# Processing colocated node 2
# Processing colocated node 3
# Processing colocated node 4
# Processing colocated node 5
# Processing colocated node 6
# Processing colocated node 7
# Processing colocated node 8
# Processing colocated node 9
# Processing colocated node 10
# Processing colocated node 11
# Processing colocated node 12
# Processing colocated node 13
# Processing colocated node 14
# Processing colocated node 15
# Processing colocated node 16
# Processing colocated node 17
# Processing colocated node 18
# Processing colocated node 19
# Processing colocated node 20
# Processing colocated node 21
# Processing colocated node 22
# Processing colocated node 23
# Processing colocated node 24
# Processing colocated node 25
# Processing colocated node 26
# Processing colocated node 27
# Processing colocated node 28
# Processing colocated node 29
# Processing colocated node 30
# Processing colocated node 31
# Processing colocated node 32
# Processing colocated node 33
# Processing colocated node 34
# Processing colocated node 35
# Processing colocated node 36
# Processing colocated node 37
# Processing colocated node 38
# Processing Year:  7
# Processing standalone node 39
# Processing standalone node 40
# Processing standalone node 41
# Processing standalone node 42
# Processing standalone node 43
# Processing standalone node 44
# Processing standalone node 45
# Processing standalone node 46
# Processing standalone node 47
# Processing standalone node 48
# Processing standalone node 49
# Processing standalone node 50
# Processing standalone node 51
# Processing standalone node 52
# Processing standalone node 53
# Processing standalone node 54
# Processing standalone node 55
# Processing standalone node 56
# Processing standalone node 57
# Processing standalone node 58
# Processing standalone node 59
# Processing standalone node 60
# Processing standalone node 61
# Processing standalone node 62
# Processing standalone node 63
# Processing standalone node 64
# Processing standalone node 65
# Processing standalone node 66
# Processing standalone node 67
# Processing standalone node 68
# Processing standalone node 69
# Processing standalone node 70
# Processing standalone node 71
# Processing standalone node 72
# Processing standalone node 73
# Processing standalone node 74
# Processing standalone node 75
# Processing standalone node 76
# Processing standalone node 77
# Processing standalone node 78
# Processing standalone node 79
# Processing standalone node 80
# Processing standalone node 81
# Processing standalone node 82
# Processing standalone node 83
# Processing standalone node 84
# Processing standalone node 85
# Processing standalone node 86
# Processing standalone node 87
# Processing standalone node 88
# Processing standalone node 89
# Processing standalone node 90
# Processing standalone node 91
# Processing standalone node 92
# Processing standalone node 93
# Processing standalone node 94
# Processing standalone node 95
# Processing standalone node 96
# Processing standalone node 97
# Processing standalone node 98
# Processing standalone node 99
# Processing standalone node 100
# Processing standalone node 101
# Processing standalone node 102
# Processing standalone node 103
# Processing standalone node 104
# Processing standalone node 105
# Processing standalone node 106
# Processing standalone node 107
# Processing standalone node 108
# Processing standalone node 109
# Processing standalone node 110
# Processing standalone node 111
# Processing standalone node 112
# Processing standalone node 113
# Processing standalone node 114
# Processing standalone node 115
# Processing standalone node 116
# Processing standalone node 117
# Processing standalone node 118
# Processing standalone node 119
# Processing standalone node 120
# Processing standalone node 121
# Processing standalone node 122
# Processing standalone node 123
# Processing standalone node 124
# Processing standalone node 125
# Processing standalone node 126
# Processing standalone node 127
# Processing standalone node 128
# Processing standalone node 129
# Processing standalone node 130
# Processing standalone node 131
# Processing standalone node 132
# Processing standalone node 133
# Processing standalone node 134
# Processing standalone node 135
# Processing standalone node 136
# Processing standalone node 137
# Processing standalone node 138
# Processing standalone node 139
# Processing standalone node 140
# Processing standalone node 141
# Processing standalone node 142
# Processing standalone node 143
# Processing standalone node 144
# Processing standalone node 145
# Processing standalone node 146
# Processing standalone node 147
# Processing standalone node 148
# Processing standalone node 149
# Processing standalone node 150
# Processing standalone node 151
# Processing standalone node 152
# Processing standalone node 153
# Processing standalone node 154
# Processing standalone node 155
# Processing standalone node 156
# Processing colocated node 0
# Processing colocated node 1
# Processing colocated node 2
# Processing colocated node 3
# Processing colocated node 4
# Processing colocated node 5
# Processing colocated node 6
# Processing colocated node 7
# Processing colocated node 8
# Processing colocated node 9
# Processing colocated node 10
# Processing colocated node 11
# Processing colocated node 12
# Processing colocated node 13
# Processing colocated node 14
# Processing colocated node 15
# Processing colocated node 16
# Processing colocated node 17
# Processing colocated node 18
# Processing colocated node 19
# Processing colocated node 20
# Processing colocated node 21
# Processing colocated node 22
# Processing colocated node 23
# Processing colocated node 24
# Processing colocated node 25
# Processing colocated node 26
# Processing colocated node 27
# Processing colocated node 28
# Processing colocated node 29
# Processing colocated node 30
# Processing colocated node 31
# Processing colocated node 32
# Processing colocated node 33
# Processing colocated node 34
# Processing colocated node 35
# Processing colocated node 36
# Processing colocated node 37
# Processing colocated node 38
# Processing Year:  8
# Processing standalone node 39
# Processing standalone node 40
# Processing standalone node 41
# Processing standalone node 42
# Processing standalone node 43
# Processing standalone node 44
# Processing standalone node 45
# Processing standalone node 46
# Processing standalone node 47
# Processing standalone node 48
# Processing standalone node 49
# Processing standalone node 50
# Processing standalone node 51
# Processing standalone node 52
# Processing standalone node 53
# Processing standalone node 54
# Processing standalone node 55
# Processing standalone node 56
# Processing standalone node 57
# Processing standalone node 58
# Processing standalone node 59
# Processing standalone node 60
# Processing standalone node 61
# Processing standalone node 62
# Processing standalone node 63
# Processing standalone node 64
# Processing standalone node 65
# Processing standalone node 66
# Processing standalone node 67
# Processing standalone node 68
# Processing standalone node 69
# Processing standalone node 70
# Processing standalone node 71
# Processing standalone node 72
# Processing standalone node 73
# Processing standalone node 74
# Processing standalone node 75
# Processing standalone node 76
# Processing standalone node 77
# Processing standalone node 78
# Processing standalone node 79
# Processing standalone node 80
# Processing standalone node 81
# Processing standalone node 82
# Processing standalone node 83
# Processing standalone node 84
# Processing standalone node 85
# Processing standalone node 86
# Processing standalone node 87
# Processing standalone node 88
# Processing standalone node 89
# Processing standalone node 90
# Processing standalone node 91
# Processing standalone node 92
# Processing standalone node 93
# Processing standalone node 94
# Processing standalone node 95
# Processing standalone node 96
# Processing standalone node 97
# Processing standalone node 98
# Processing standalone node 99
# Processing standalone node 100
# Processing standalone node 101
# Processing standalone node 102
# Processing standalone node 103
# Processing standalone node 104
# Processing standalone node 105
# Processing standalone node 106
# Processing standalone node 107
# Processing standalone node 108
# Processing standalone node 109
# Processing standalone node 110
# Processing standalone node 111
# Processing standalone node 112
# Processing standalone node 113
# Processing standalone node 114
# Processing standalone node 115
# Processing standalone node 116
# Processing standalone node 117
# Processing standalone node 118
# Processing standalone node 119
# Processing standalone node 120
# Processing standalone node 121
# Processing standalone node 122
# Processing standalone node 123
# Processing standalone node 124
# Processing standalone node 125
# Processing standalone node 126
# Processing standalone node 127
# Processing standalone node 128
# Processing standalone node 129
# Processing standalone node 130
# Processing standalone node 131
# Processing standalone node 132
# Processing standalone node 133
# Processing standalone node 134
# Processing standalone node 135
# Processing standalone node 136
# Processing standalone node 137
# Processing standalone node 138
# Processing standalone node 139
# Processing standalone node 140
# Processing standalone node 141
# Processing standalone node 142
# Processing standalone node 143
# Processing standalone node 144
# Processing standalone node 145
# Processing standalone node 146
# Processing standalone node 147
# Processing standalone node 148
# Processing standalone node 149
# Processing standalone node 150
# Processing standalone node 151
# Processing standalone node 152
# Processing standalone node 153
# Processing standalone node 154
# Processing standalone node 155
# Processing standalone node 156
# Processing colocated node 0
# Processing colocated node 1
# Processing colocated node 2
# Processing colocated node 3
# Processing colocated node 4
# Processing colocated node 5
# Processing colocated node 6
# Processing colocated node 7
# Processing colocated node 8
# Processing colocated node 9
# Processing colocated node 10
# Processing colocated node 11
# Processing colocated node 12
# Processing colocated node 13
# Processing colocated node 14
# Processing colocated node 15
# Processing colocated node 16
# Processing colocated node 17
# Processing colocated node 18
# Processing colocated node 19
# Processing colocated node 20
# Processing colocated node 21
# Processing colocated node 22
# Processing colocated node 23
# Processing colocated node 24
# Processing colocated node 25
# Processing colocated node 26
# Processing colocated node 27
# Processing colocated node 28
# Processing colocated node 29
# Processing colocated node 30
# Processing colocated node 31
# Processing colocated node 32
# Processing colocated node 33
# Processing colocated node 34
# Processing colocated node 35
# Processing colocated node 36
# Processing colocated node 37
# Processing colocated node 38
# Processing Year:  9
# Processing standalone node 39
# Processing standalone node 40
# Processing standalone node 41
# Processing standalone node 42
# Processing standalone node 43
# Processing standalone node 44
# Processing standalone node 45
# Processing standalone node 46
# Processing standalone node 47
# Processing standalone node 48
# Processing standalone node 49
# Processing standalone node 50
# Processing standalone node 51
# Processing standalone node 52
# Processing standalone node 53
# Processing standalone node 54
# Processing standalone node 55
# Processing standalone node 56
# Processing standalone node 57
# Processing standalone node 58
# Processing standalone node 59
# Processing standalone node 60
# Processing standalone node 61
# Processing standalone node 62
# Processing standalone node 63
# Processing standalone node 64
# Processing standalone node 65
# Processing standalone node 66
# Processing standalone node 67
# Processing standalone node 68
# Processing standalone node 69
# Processing standalone node 70
# Processing standalone node 71
# Processing standalone node 72
# Processing standalone node 73
# Processing standalone node 74
# Processing standalone node 75
# Processing standalone node 76
# Processing standalone node 77
# Processing standalone node 78
# Processing standalone node 79
# Processing standalone node 80
# Processing standalone node 81
# Processing standalone node 82
# Processing standalone node 83
# Processing standalone node 84
# Processing standalone node 85
# Processing standalone node 86
# Processing standalone node 87
# Processing standalone node 88
# Processing standalone node 89
# Processing standalone node 90
# Processing standalone node 91
# Processing standalone node 92
# Processing standalone node 93
# Processing standalone node 94
# Processing standalone node 95
# Processing standalone node 96
# Processing standalone node 97
# Processing standalone node 98
# Processing standalone node 99
# Processing standalone node 100
# Processing standalone node 101
# Processing standalone node 102
# Processing standalone node 103
# Processing standalone node 104
# Processing standalone node 105
# Processing standalone node 106
# Processing standalone node 107
# Processing standalone node 108
# Processing standalone node 109
# Processing standalone node 110
# Processing standalone node 111
# Processing standalone node 112
# Processing standalone node 113
# Processing standalone node 114
# Processing standalone node 115
# Processing standalone node 116
# Processing standalone node 117
# Processing standalone node 118
# Processing standalone node 119
# Processing standalone node 120
# Processing standalone node 121
# Processing standalone node 122
# Processing standalone node 123
# Processing standalone node 124
# Processing standalone node 125
# Processing standalone node 126
# Processing standalone node 127
# Processing standalone node 128
# Processing standalone node 129
# Processing standalone node 130
# Processing standalone node 131
# Processing standalone node 132
# Processing standalone node 133
# Processing standalone node 134
# Processing standalone node 135
# Processing standalone node 136
# Processing standalone node 137
# Processing standalone node 138
# Processing standalone node 139
# Processing standalone node 140
# Processing standalone node 141
# Processing standalone node 142
# Processing standalone node 143
# Processing standalone node 144
# Processing standalone node 145
# Processing standalone node 146
# Processing standalone node 147
# Processing standalone node 148
# Processing standalone node 149
# Processing standalone node 150
# Processing standalone node 151
# Processing standalone node 152
# Processing standalone node 153
# Processing standalone node 154
# Processing standalone node 155
# Processing standalone node 156
# Processing colocated node 0
# Processing colocated node 1
# Processing colocated node 2
# Processing colocated node 3
# Processing colocated node 4
# Processing colocated node 5
# Processing colocated node 6
# Processing colocated node 7
# Processing colocated node 8
# Processing colocated node 9
# Processing colocated node 10
# Processing colocated node 11
# Processing colocated node 12
# Processing colocated node 13
# Processing colocated node 14
# Processing colocated node 15
# Processing colocated node 16
# Processing colocated node 17
# Processing colocated node 18
# Processing colocated node 19
# Processing colocated node 20
# Processing colocated node 21
# Processing colocated node 22
# Processing colocated node 23
# Processing colocated node 24
# Processing colocated node 25
# Processing colocated node 26
# Processing colocated node 27
# Processing colocated node 28
# Processing colocated node 29
# Processing colocated node 30
# Processing colocated node 31
# Processing colocated node 32
# Processing colocated node 33
# Processing colocated node 34
# Processing colocated node 35
# Processing colocated node 36
# Processing colocated node 37
# Processing colocated node 38
# Processing Year:  10
# Processing standalone node 39
# Processing standalone node 40
# Processing standalone node 41
# Processing standalone node 42
# Processing standalone node 43
# Processing standalone node 44
# Processing standalone node 45
# Processing standalone node 46
# Processing standalone node 47
# Processing standalone node 48
# Processing standalone node 49
# Processing standalone node 50
# Processing standalone node 51
# Processing standalone node 52
# Processing standalone node 53
# Processing standalone node 54
# Processing standalone node 55
# Processing standalone node 56
# Processing standalone node 57
# Processing standalone node 58
# Processing standalone node 59
# Processing standalone node 60
# Processing standalone node 61
# Processing standalone node 62
# Processing standalone node 63
# Processing standalone node 64
# Processing standalone node 65
# Processing standalone node 66
# Processing standalone node 67
# Processing standalone node 68
# Processing standalone node 69
# Processing standalone node 70
# Processing standalone node 71
# Processing standalone node 72
# Processing standalone node 73
# Processing standalone node 74
# Processing standalone node 75
# Processing standalone node 76
# Processing standalone node 77
# Processing standalone node 78
# Processing standalone node 79
# Processing standalone node 80
# Processing standalone node 81
# Processing standalone node 82
# Processing standalone node 83
# Processing standalone node 84
# Processing standalone node 85
# Processing standalone node 86
# Processing standalone node 87
# Processing standalone node 88
# Processing standalone node 89
# Processing standalone node 90
# Processing standalone node 91
# Processing standalone node 92
# Processing standalone node 93
# Processing standalone node 94
# Processing standalone node 95
# Processing standalone node 96
# Processing standalone node 97
# Processing standalone node 98
# Processing standalone node 99
# Processing standalone node 100
# Processing standalone node 101
# Processing standalone node 102
# Processing standalone node 103
# Processing standalone node 104
# Processing standalone node 105
# Processing standalone node 106
# Processing standalone node 107
# Processing standalone node 108
# Processing standalone node 109
# Processing standalone node 110
# Processing standalone node 111
# Processing standalone node 112
# Processing standalone node 113
# Processing standalone node 114
# Processing standalone node 115
# Processing standalone node 116
# Processing standalone node 117
# Processing standalone node 118
# Processing standalone node 119
# Processing standalone node 120
# Processing standalone node 121
# Processing standalone node 122
# Processing standalone node 123
# Processing standalone node 124
# Processing standalone node 125
# Processing standalone node 126
# Processing standalone node 127
# Processing standalone node 128
# Processing standalone node 129
# Processing standalone node 130
# Processing standalone node 131
# Processing standalone node 132
# Processing standalone node 133
# Processing standalone node 134
# Processing standalone node 135
# Processing standalone node 136
# Processing standalone node 137
# Processing standalone node 138
# Processing standalone node 139
# Processing standalone node 140
# Processing standalone node 141
# Processing standalone node 142
# Processing standalone node 143
# Processing standalone node 144
# Processing standalone node 145
# Processing standalone node 146
# Processing standalone node 147
# Processing standalone node 148
# Processing standalone node 149
# Processing standalone node 150
# Processing standalone node 151
# Processing standalone node 152
# Processing standalone node 153
# Processing standalone node 154
# Processing standalone node 155
# Processing standalone node 156
# Processing colocated node 0
# Processing colocated node 1
# Processing colocated node 2
# Processing colocated node 3
# Processing colocated node 4
# Processing colocated node 5
# Processing colocated node 6
# Processing colocated node 7
# Processing colocated node 8
# Processing colocated node 9
# Processing colocated node 10
# Processing colocated node 11
# Processing colocated node 12
# Processing colocated node 13
# Processing colocated node 14
# Processing colocated node 15
# Processing colocated node 16
# Processing colocated node 17
# Processing colocated node 18
# Processing colocated node 19
# Processing colocated node 20
# Processing colocated node 21
# Processing colocated node 22
# Processing colocated node 23
# Processing colocated node 24
# Processing colocated node 25
# Processing colocated node 26
# Processing colocated node 27
# Processing colocated node 28
# Processing colocated node 29
# Processing colocated node 30
# Processing colocated node 31
# Processing colocated node 32
# Processing colocated node 33
# Processing colocated node 34
# Processing colocated node 35
# Processing colocated node 36
# Processing colocated node 37
# Processing colocated node 38
